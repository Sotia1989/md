# %%
ErsterVersuch:


print("Kasse-Obstladen")
print("-----------------------")
print()

anzahlaepfel = int(input ("Wie viele Äpfel möchtest du kaufen? "))
anzahlbirnen = int(input ("Wie viele Birnen möchtest du kaufen? "))
anzahlbananen = int(input ("Wie viele Bananen möchtest du kaufen? "))

lageraepfel = 6
lagerbirnen = 5
lagerbananen = 4
                    
preisaepfel = 1.80
preisbirnen = 1.60
preisbananen = 1.50

summe = 0.0
gegeben = 0.0
rueckgeld = 0.0

warenkorb = 0

if anzahlaepfel>lageraepfel:
    print("Leider haben wir nicht genug Äpfel auf Lager")
    print(anzahlaepfel)
elif anzahlbirnen>lagerbirnen:
    print("Leider haben wir nicht genug Birnen auf Lager")
    print(anzahlbirnen)
elif anzahlbananen>lagerbananen:
    print("Leider haben wir nicht genug Bananen auf Lager")
    print(anzahlbananen)
else:
    print("Ok, deine Bestellung wird ausgeführt.")
    delay(500)
# Out:
# Kasse-Obstladen
# -----------------------
#
# Wie viele Äpfel möchtest du kaufen? 9
# Wie viele Birnen möchtest du kaufen? 9
# Wie viele Bananen möchtest du kaufen? 9
# Leider haben wir nicht genug Äpfel auf Lager
# 9

# %%
print("Kasse-Obstladen")
print("-----------------------")
print()

bestellaepfel = 0
bestellbirnen = 0
bestellbananen = 0

lageraepfel = 6
lagerbirnen = 5
lagerbananen = 4
                    
preisaepfel = 1.80
preisbirnen = 1.60
preisbananen = 1.50

warenkorb = 0

bestellaepfel = int(input ("Wie viele Äpfel möchtest du kaufen? "))
if bestellaepfel <= lageraepfel:
    print()
    print(bestellaepfel, "Apfel/Äpfel dem Warenkorb hinzugefügt")
    print("%.2f" % (preisaepfel*bestellaepfel), "Euro kosten die Äpfel zusammen")
    print()
else:
    bestellaepfel > lageraepfel
    print()
    print("Leider haben wir nur noch ", lageraepfel, "auf Lager.")
    bestellaepfel = int(input ("Wie viele Äpfel möchtest du stattdessen kaufen? "))
    if bestellaepfel > lageraepfel:
        print("Leider haben wir nur noch ", lageraepfel, "auf Lager.")
        bestellaepfel = int(input ("Wie viele Äpfel möchtest du stattdessen kaufen? "))
    print()
    print(bestellaepfel, "Apfel/Äpfel dem Warenkorb hinzugefügt")
    print()
    print("%.2f" % (preisaepfel*bestellaepfel), "Euro kosten die Äpfel zusammen.")
    print()
    
bestellbirnen = int(input ("Wie viele Birnen möchtest du kaufen? "))
if bestellbirnen <= lagerbirnen:
    print()
    print(bestellbirnen, "Birne/n dem Warenkorb hinzugefügt")
    print("%.2f" % (preisbirnen*bestellbirnen), "Euro kosten die Birnen zusammen")
    print()
else:
    bestellbirnen > lagerbirnen
    print()
    print("Leider haben wir nur noch ", lagerbirnen, "auf Lager.")
    bestellbirnen = int(input ("Wie viele Birnen möchtest du stattdessen kaufen? "))
    if bestellbirnen > lagerbirnen:
        print("Leider haben wir nur noch ", lagerbirnen, "auf Lager.")
        bestellbirnen = int(input ("Wie viele Birnen möchtest du stattdessen kaufen? "))
    print()
    print(bestellbirnen, "Birne/n dem Warenkorb hinzugefügt")
    print()
    print("%.2f" % (preisbirnen*bestellbirnen), "Euro kosten die Birnen zusammen.")
    print()
    
bestellbananen = int(input ("Wie viele Bananen möchtest du kaufen? "))
if bestellbananen <= lagerbananen:
    print()
    print(bestellbananen, "Banane/n dem Warenkorb hinzugefügt")
    print("%.2f" % (preisbananen*bestellbananen), "Euro kosten die Bananen zusammen")
    print()
else:
    bestellbananen > lagerbananen
    print()
    print("Leider haben wir nur noch ", lagerbananen, "auf Lager.")
    bestellbananen = int(input ("Wie viele Bananen möchtest du stattdessen kaufen? "))
    if bestellbananen > lagerbananen:
        print("Leider haben wir nur noch ", lagerbananen, "auf Lager.")
        bestellbananen = int(input ("Wie viele Bananen möchtest du stattdessen kaufen? "))
    print()
    print(bestellbananen, "Banane/n dem Warenkorb hinzugefügt")
    print()
    print("%.2f" % (preisbananen*bestellbananen), "Euro kosten die Bananen zusammen.")
    print()

print("--------------Bestellbestätigung----------------")
print()

summe = 0.0
gegeben = 0.0
rueckgeld = 0.0

print("Es befinden sich ", (bestellaepfel+bestellbananen+bestellbirnen), " Artikel im Warenkorb")
summe = (bestellaepfel*preisaepfel) + (bestellbirnen*preisbirnen) + (bestellbananen*preisbananen)
print("Zu zahlen sind: ""%.2f" % summe, "Euro")
print()
gegeben = float((input("Wie viel gibst du? ")))
rueckgeld = gegeben-summe

if rueckgeld<0:
    print("Das reicht leider nicht.")
    print(float(input("Wie viel gibst du?")))
    rueckgeld>=0
    print()
    print("Vielen Dank.")
    print("Du erhälst", "%.2f" % rueckgeld, "Euro zurück")
else:
    rueckgeld>=0
    print()
    print("Vielen Dank.")
    print("Du erhälst", "%.2f" % rueckgeld, "Euro zurück")
# Out:
# Kasse-Obstladen
# -----------------------
#
# Wie viele Äpfel möchtest du kaufen? 11
#
# Leider haben wir nur noch  6 auf Lager.
# Wie viele Äpfel möchtest du stattdessen kaufen? 1
#
# 1 Apfel/Äpfel dem Warenkorb hinzugefügt
#
# 1.80 Euro kosten die Äpfel zusammen.
#
# Wie viele Birnen möchtest du kaufen? 1
#
# 1 Birne/n dem Warenkorb hinzugefügt
# 1.60 Euro kosten die Birnen zusammen
#
# Wie viele Bananen möchtest du kaufen? 1
#
# 1 Banane/n dem Warenkorb hinzugefügt
# 1.50 Euro kosten die Bananen zusammen
#
# --------------Bestellbestätigung----------------
#
# Es befinden sich  3  Artikel im Warenkorb
# Zu zahlen sind: 4.90 Euro
#
# Wie viel gibst du? 1
# Das reicht leider nicht.
# Wie viel gibst du?5
# 5.0
#
# Vielen Dank.
# Du erhälst -3.90 Euro zurück

# %% [markdown]
# summe = (bestell_apfel * preis_apfel) + (bestell_birne * preis_birne) + (bestell_bananen * preis_banane)
#
# print("%.2f" % rueckgeld, 'Euro')
